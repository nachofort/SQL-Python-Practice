# %%
# librerias
import random

#Definiciones

estadisticas={}

def Menu():
    print("1. Partida modo solitario\2. Partida 2 Jugadores\3. Estadística\4. Salir")
    opcion=input("Elige una opción: ")
    opcion=Valida_Menu(1, 4):

def Submenu():
    print("1. Facil(20 intentos)\2. Medio(12 intentos)\3. Dificil(5 intentos\4. Volver al menú principal")
    subopcion=input("Elige una opción: ")
    subopcion=Valida_Submenu(1, 4):

def Valida_Menu(minimo,maximo):
    opcion=0
    while opcion<minimo or opcion>maximo:
        opcion=int(input("Escribe una opcion entre {minimo} y {maximo}: "))

def Valida_Submenu(minimo,maximo):
    subopcion=0
    while opcion<minimo or opcion>maximo:
        opcion=int(input("Escribe una opcion entre {minimo} y {maximo}: "))

def Valida_numero1(minimo,maximo):
    numero2=0
    while numero2<minimo or numero2>maximo:
        opcion=int(input("Escribe un número entre {minimo} y {maximo}: "))
    return opcion

def Valida_numero2(minimo,maximo):
    numero2=0
    while numero2<minimo or numero2>maximo:
        opcion=int(input("Escribe un número entre {minimo} y {maximo}: "))
    return opcion

def opcion1():
    jugador1=input("Escribe tu nombre: ")
    numero1=random.randint(1,1000)
    numero2= int(input("Adivina el número que estoy pensando: "))
    numero2=Valida_numero2(1,1000)
    for i in range(n):
        if numero2 < numero1:
            print("El número es mayor")
            numero2=int(input("Adivina el número que estoy pensando: "))
            numero2=Valida_numero2(1,1000)
        elif numero2 > numero1:
            print("El número es menor")
            numero2=int(input("Adivina el número que estoy pensando: "))
            numero2=Valida_numero2(1,1000)
        else:
            print("¡Felicidades! Has adivinado el número.")
            estadisticas.update({"jugador1": jugador1, "jugador2": "CPU", "ganador": jugador1, "intentos": i+1})
            break
    else:
        print(f"Lo siento, no has adivinado el número. Era {numero1}.")
        estadisticas.update({"jugador1": jugador1, "jugador2": "CPU", "ganador": "CPU", "intentos": n})

def opcion2():
    jugador1=input("Escribe tu nombre: ")
    numero1=int(input("Jugador 1, escribe un número entre 1 y 1000: "))
    numero1=Valida_numero1(1,1000)
    jugador2=input("Escribe tu nombre: ")
    numero2=int(input("Jugador 2, adivina el número del Jugador 1: "))
    numero2=Valida_numero2(1,1000)
    for i in range(n):
    if numero2 < numero1:
        print("El número es mayor")
        numero2=int(input("Adivina el número que estoy pensando: "))
        numero2=Valida_numero2(1,1000)
    elif numero2 > numero1:
        print("El número es menor")
        numero2=int(input("Adivina el número que estoy pensando: "))
        numero2=Valida_numero2(1,1000)
    else:
        print(f"¡Felicidades {jugador2}! Has adivinado el número.")
        estadisticas.update({"jugador1": jugador1, "jugador2": jugador2, "ganador": jugador2, "intentos": i+1})
        break
else:
    print(f"Lo siento, no has adivinado el número. Era {numero1}.")
    print(f"¡Felicidades {jugador1}! Has ganado la partida.")
    estadisticas.update({"jugador1": jugador1, "jugador2": jugador2, "ganador": jugador1, "intentos": n})
    
def opcion3():
    print(estadisticas)

def opcion4():

#Programa principal
Menu()
Submenu()
if subopcion==1:
    n=20
elif subopcion==2:
    n=12
elif subopcion==3:
    n=5
elif subopcion==4:
    Menu()

if opcion==1:
    opcion1()
elif opcion==2:
    opcion2()
elif opcion==3:
    opcion3()
elif opcion==4:
    print("¡Gracias por jugar!")
    exit()
